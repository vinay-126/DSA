# %% [markdown]
# <a href="https://colab.research.google.com/github/vinay-126/DSA/blob/main/Task_5_Databyte_107121126.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# IMPORTED EXCEL FILE.

# %%
url='/content/drive/MyDrive/Colab Notebooks/Football Players (1).xlsx'

# %%
df=pd.read_excel(url)

# %%
df.head(5)
# Out:
#    Wage ($)    Value ($)               Name   Age  \
# 0  491304.0   83043478.0  Cristiano Ronaldo  32.0
# 1  491304.0   91304348.0           L. Messi  30.0
# 2  243478.0  106956522.0             Neymar  25.0
# 3  443478.0   84347826.0          L. Suárez  30.0
# 4  200000.0   53043478.0           M. Neuer  31.0
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png     94.0       94.0
# 1  https://cdn.sofifa.org/flags/52.png     93.0       93.0
# 2  https://cdn.sofifa.org/flags/54.png     92.0       94.0
# ...

# %%
df.loc[df['Overall']>90,'Penalties']
# Out:
# 0    85.0
# 1    74.0
# 2    81.0
# 3    85.0
# 4    47.0
# 5    81.0
# Name: Penalties, dtype: float64

# %%
nogk=pd.DataFrame()

# %%
nogk=df.loc[df['GK diving']>50]

# %% [markdown]
# nogk is data without data of goalkeepers.

# %%
nogk
# Out:
#        Wage ($)   Value ($)           Name   Age  \
# 4      200000.0  53043478.0       M. Neuer  31.0
# 6      186957.0  56086957.0         De Gea  26.0
# 12     165217.0  51304348.0    T. Courtois  25.0
# 18      95652.0   3913043.0      G. Buffon  39.0
# 20      71304.0  49565217.0       J. Oblak  24.0
# ...         ...         ...            ...   ...
# 17894     870.0     43478.0  S. Więckowicz  17.0
# 17901     870.0     26087.0       N. Maher  18.0
# 17908     870.0     43478.0   M. Al Baqawi  19.0
# 17919     870.0     43478.0       W. Henry  18.0
# 17945     870.0     43478.0      A. Dillon  20.0
#
#                                                  Photo          Nationality  \
# 4      https://cdn.sofifa.org/48/18/players/167495.png              Germany
# 6      https://cdn.sofifa.org/48/18/players/193080.png                Spain
# 12     https://cdn.sofifa.org/48/18/players/192119.png              Belgium
# ...

# %%
df.describe()
# Out:
#             Wage ($)     Value ($)           Age       Overall     Potential  \
# count   17981.000000  1.798100e+04  17981.000000  17981.000000  17981.000000
# mean    10040.937212  2.074252e+06     25.144541     66.247984     71.190813
# std     20069.511431  4.655626e+06      4.614272      6.987965      6.102199
# min         0.000000  0.000000e+00     16.000000     46.000000     46.000000
# 25%      1739.000000  2.608700e+05     21.000000     62.000000     67.000000
# 50%      3478.000000  5.869570e+05     25.000000     66.000000     71.000000
# 75%     10435.000000  1.826087e+06     28.000000     71.000000     75.000000
# max    491304.000000  1.069565e+08     47.000000     94.000000     94.000000
#
#        Acceleration    Aggression       Agility       Balance  Ball control  \
# count  17897.000000  17913.000000  17910.000000  17924.000000  17840.000000
# mean      64.576521     55.791492     63.333613     63.803894     58.071469
# ...

# %%
top50=pd.DataFrame

# %%
top50=df.loc[df['Overall']>86 ]

# %%
agg=list(df.Aggression)

# %%
finish=list(df.Finishing)

# %%
res1=agg[1:100]
res2=finish[1:100]

# %% [markdown]
# Plotting of graph between aggression and finishing

# %%
res1.sort()
res2.sort()
plt.plot(res1,res2)
plt.xlabel("Aggression")
plt.title('Finishing v/s Aggression')
plt.ylabel("Finishing")
plt.show()

# %%
reac=list(df.Reactions)
ove=list(df.Overall)
res3=reac[1:100]
res4=ove[1:100]
plt.plot(res4,res3)
plt.title('Overall performnace v/s Reactions')
plt.xlabel("Reactions")
plt.ylabel("Overall")
plt.show()

# %% [markdown]
# From above graph, we can say that as reaction time of a player increases, his overall performance increases, and can make a comment that
# Players should focus on there Reactions.

# %%
plt.figure(figsize=(12,6))
data = pd.DataFrame({"Aggression": np.random.rand(10), "Finishing": np.random.rand(10), "Overall": np.random.rand(10),"Reactions": np.random.rand(10)})
ax = data[['Aggression', 'Finishing','Overall','Reactions']].plot(kind='box', title='Boxplot')

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc(axis=0)[:]
y=df['Finishing']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
corelation=pd.DataFrame()

# %%
corelation=x_train.corr()
corelation['Dribbling']
# Out:
# Wage ($)              0.253319
# Value ($)             0.270459
# Age                   0.008413
# Overall               0.357814
# Potential             0.315251
# Acceleration          0.744047
# Aggression            0.421500
# Agility               0.762273
# Balance               0.665019
# Ball control          0.933326
# Composure             0.681383
# Crossing              0.855439
# Curve                 0.840126
# Dribbling             1.000000
# Finishing             0.824124
# Free kick accuracy    0.753231
# GK diving            -0.746455
# GK handling          -0.744621
# GK kicking           -0.740805
# GK positioning       -0.742484
# GK reflexes          -0.744943
# Heading accuracy      0.541898
# Interceptions         0.272229
# Jumping               0.119938
# Long passing          0.714151
# Long shots            0.840056
# Marking               0.236897
# Penalties             0.771321
# Positioning           0.894981
# Reactions             0.356707
# ...

# %% [markdown]
# From correlation table, we can get various insights like:
#
#
# *   Relationship between wage and value is very high, and one of them can be removed.
# *   Age is inversely proportional with acceleration and potential.
# *   Tackling is related highly with Aggression.
#
#
# *   A very important attribute of a player is Dribbling, and a player    having better dribbling quality is mostly better at Short passing, volleys, ball control,positioning, long passing., curve and penalties.
#
#
# *   And various insights like above, can be made.

# %% [markdown]
# So, we can safely say that even if we remove other columns such as positioning, penalties, curve, ball control, free kick accuracy, short & long passing, we can get them by help of only dribbling data..

# %%
figure,axis=plt.subplots(2,2)

drib=list(df.Dribbling)
vol=list(df.Volleys)
res5=drib[1:100]
res6=vol[1:100]

axis[0,0].plot(res5,res6)
axis[0,0].set_title('Volleys vs Dribbling')

pos=list(df.Positioning)
res7=pos[1:100]

axis[0,1].plot(res5,res7)
axis[0,1].set_title('Positioning vs Dribbling')

curve=list(df.Curve)
res8=curve[1:100]

axis[1,0].plot(res5,res8)
axis[1,0].set_title('Curve vs Dribbling')

con=list(df.Crossing)
res9=con[1:100]

axis[1,1].plot(res5,res9)
axis[1,1].set_title('Crossing vs Dribbling')
plt.show()

# %% [markdown]
# We can confirm our data about dribbling from above cases also.

# %%
corelation=x_train.corr()
plt.figure(figsize=(5,7))
import seaborn as sns
sns.set_theme(font_scale=1)
cor=x_train.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.CMRmap_r)
plt.show()
